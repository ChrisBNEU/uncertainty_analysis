# %%
from PIL import Image

# %%
im = Image.open("dm_output_1.eps")
im.save("dm_output_1.png")
display(Image.open("dm_output_1.png"))
# Out:
# gs: /shared/centos7/anaconda3/2021.05/lib/libtiff.so.5: no version information available (required by /lib64/libgs.so.9)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=720x720 at 0x2AE2FD6BD710>

# %%
im = Image.open("dm_output_2.eps")
im.save("dm_output_2.png")
display(Image.open("dm_output_2.png"))
# Out:
# gs: /shared/centos7/anaconda3/2021.05/lib/libtiff.so.5: no version information available (required by /lib64/libgs.so.9)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=720x720 at 0x2AE2FD6BD150>

# %%
file = "sens_total.eps"
file_png = file.replace(".eps", ".png")
im = Image.open(file)
im.save(file_png)
display(Image.open(file_png))
# Out:
# gs: /shared/centos7/anaconda3/2021.05/lib/libtiff.so.5: no version information available (required by /lib64/libgs.so.9)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1440x864 at 0x2AE2FD6BD990>

# %%
file = "sens_main.eps"
file_png = file.replace(".eps", ".png")
im = Image.open(file)
im.save(file_png)
display(Image.open(file_png))
# Out:
# gs: /shared/centos7/anaconda3/2021.05/lib/libtiff.so.5: no version information available (required by /lib64/libgs.so.9)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1440x864 at 0x2AE2FD6BDDD0>
